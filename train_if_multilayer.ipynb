# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from dataloaders import Dataloader, MnistSpikesDataloader
from spiking import iterate_spikes, SpikingModule
from spiking.multilayer import IntegrateAndFireMultilayer, SpikingMultilayer
from spiking.learning import STDP
from spiking.competition import WinnerTakesAll

from visualization import SpikesVisualization

# %%
dataloader = MnistSpikesDataloader("./data/mnist-subset", 'train')
validation_dataloader = MnistSpikesDataloader("./data/mnist-subset", 'test')
max_x, max_y = dataloader.inputs[0].shape
max_z = 2
max_input_spikes = max_x * max_y * max_z
print(f"{max_input_spikes = }")
# Out:
# max_input_spikes = 1568

# %%
def train(model: IntegrateAndFireMultilayer, num_epochs: int):
    for epoch_idx in range(1, num_epochs + 1):
        for batch_idx, (spikes, label, times) in enumerate(dataloader.iterate(batch_size=1), start=1):
            membrane_potentials = []
            membrane_potentials_times = []
            
            for incoming_spikes, current_time, dt in iterate_spikes(spikes, shape=(max_x, max_y, max_z)):
                output_spike = model.forward(incoming_spikes.flatten(), current_time=current_time, dt=dt)
                
                if np.any(output_spike == 1.0):
                    membrane_potentials.append([
                        neuron.threshold if output_spike[neuron_idx] else neuron.membrane_potential
                        for neuron_idx, neuron in enumerate(model.layers[-1].neurons)
                    ])
                    membrane_potentials_times.append(current_time)
                membrane_potentials.append([neuron.membrane_potential for neuron in model.layers[-1].neurons])
                membrane_potentials_times.append(current_time)
            
            pre_spike_times = times.flatten()
            model.backward(pre_spike_times)
            post_spike_times = model.spike_times
    
            if epoch_idx % 10 == 0 and batch_idx <= 3:
                SpikesVisualization.plot_pre_post_spikes(
                    pre_spike_times,
                    post_spike_times,
                    title=f"Pre-synaptic vs Post-synaptic. Epoch {epoch_idx} - Batch {batch_idx} - Label {label}",
                    unique_colors=True
                )
                SpikesVisualization.plot_multiple_membrane_potentials(
                    membrane_potentials,
                    membrane_potentials_times,
                    title=f"Membrane Potential Over Time. Epoch {epoch_idx} - Batch {batch_idx} - Label {label}"
                )
            
            model.reset()

def dataloader_to_spike_times(model: IntegrateAndFireMultilayer, arg_dataloader: Dataloader):
    X, y = [], []
    for batch_idx, (spikes, label, _) in enumerate(arg_dataloader.iterate(batch_size=1), start=1):
        for incoming_spikes, current_time, dt in iterate_spikes(spikes, shape=(max_x, max_y, max_z)):
            model.forward(incoming_spikes.flatten(), current_time=current_time, dt=dt)
        X.append(np.clip(model.spike_times, -1.5, 1.5))  # because of infinities
        y.append(label)
        model.reset()
    return np.array(X), np.array(y)

def eval_snn(model: IntegrateAndFireMultilayer):
    X_train, y_train = dataloader_to_spike_times(model, dataloader)
    X_test, y_test = dataloader_to_spike_times(model, validation_dataloader)
    print(f"{X_train.shape = }, {y_train.shape = }")
    print(f"{X_test.shape = }, {y_test.shape = }")

    classifier = LinearSVC()
    classifier.fit(X_train, y_train)
    
    print("Train accuracy:", accuracy_score(y_train, classifier.predict(X_train)))
    
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_train)
    
    scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_train, cmap='viridis', edgecolor='k', alpha=0.7)
    plt.colorbar(scatter, label='Class Label')
    plt.title("Train Data Visualized with PCA")
    plt.xlabel("Principal Component 1")
    plt.ylabel("Principal Component 2")
    plt.grid()
    plt.show()
    
    y_pred = classifier.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='macro')
    recall = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    print("Confusion Matrix:")
    print(conf_matrix)

def visualize_neurons_weights(model: IntegrateAndFireMultilayer, layer: int, num_neurons: int):
    for i in range(num_neurons):
        img = model.layers[layer].neurons[i].weights.reshape((max_z, max_x, max_y))
        plt.title(f"Weights {i}")
        plt.axis("off")
        plt.subplot(1, 2, 1)
        plt.imshow(img[0, :, :], cmap='grey')
        plt.axis("off")
        plt.subplot(1, 2, 2)
        plt.imshow(img[1, :, :], cmap='grey')
        plt.axis("off")
        plt.show()

# %%
stdp = STDP()
wta = WinnerTakesAll()
model1 = IntegrateAndFireMultilayer(
    num_inputs=max_input_spikes, num_hidden=[24], num_outputs=8, learning_mechanism=stdp, competition_mechanism=wta, threshold=8.0, refractory_period=np.inf
)

# %%
train(model1, 50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train(model1, 50)
#
# Cell In[6], line 8, in train(model, num_epochs)
#       5 membrane_potentials_times = []
#       7 for incoming_spikes, current_time, dt in iterate_spikes(spikes, shape=(max_x, max_y, max_z)):
# ----> 8     output_spike = model.forward(incoming_spikes.flatten(), current_time=current_time, dt=dt)
#      10     if np.any(output_spike == 1.0):
#      11         membrane_potentials.append([
#      12             neuron.threshold if output_spike[neuron_idx] else neuron.membrane_potential
#      13             for neuron_idx, neuron in enumerate(model.layers[-1].neurons)
#      14         ])
#
# File ~/Uni/dummy-snn/spiking/multilayer/if_multilayer.py:57, in IntegrateAndFireMultilayer.forward(self, incoming_spikes, current_time, dt)
#      55 def forward(self, incoming_spikes: np.ndarray, current_time: float, dt: float):
#      56     for layer in self.layers:
# ---> 57         incoming_spikes = layer.forward(incoming_spikes, current_time, dt)
#      58     return incoming_spikes
#
# File ~/Uni/dummy-snn/spiking/layers/if_layer.py:40, in IntegrateAndFireLayer.forward(self, incoming_spikes, current_time, dt)
#      37 spikes = np.zeros(self.num_outputs, dtype=np.float32)
#      39 for neuron_idx, neuron in enumerate(self.neurons):
# ---> 40     neuron_spike = neuron.forward(
#      41         incoming_spikes=incoming_spikes, current_time=current_time, dt=dt
#      42     )
#      43     if neuron_spike == 1.0 and np.isinf(self.spike_times[neuron_idx]):
#      44         self.spike_times[neuron_idx] = current_time
#
# File ~/Uni/dummy-snn/spiking/neurons/if_neuron.py:55, in IntegrateAndFireNeuron.forward(self, incoming_spikes, current_time, dt)
#      52 if not self._update_refractory(dt):
#      53     return np.float32(0.0)
# ---> 55 return self._update_potential(incoming_spikes, current_time)
#
# File ~/Uni/dummy-snn/spiking/neurons/if_neuron.py:40, in IntegrateAndFireNeuron._update_potential(self, incoming_spikes, current_time)
#      39 def _update_potential(self, incoming_spikes: np.ndarray, current_time: float):
# ---> 40     self.membrane_potential += np.sum(self.weights[incoming_spikes == 1.0])
#      41     if self.membrane_potential < self.threshold:
#      42         return np.float32(0.0)
#
# File ~/Uni/dummy-snn/venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:2344, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2338         raise ValueError("Passing `min` or `max` keyword argument when "
#    2339                          "`a_min` and `a_max` are provided is forbidden.")
#    2341     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2344 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2345                     initial=None, where=None):
#    2346     return (a, out)
#    2349 @array_function_dispatch(_sum_dispatcher)
#    2350 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2351         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
model2 = IntegrateAndFireMultilayer(
    num_inputs=max_input_spikes, num_hidden=[24], num_outputs=8, learning_mechanism=stdp, competition_mechanism=wta, threshold=1.0, refractory_period=np.inf
)

# %%
train(model2, 50)

# %%
eval_snn(model2)
# Out:
# X_train.shape = (600, 8), y_train.shape = (600,)
# X_test.shape = (100, 8), y_test.shape = (100,)
# Train accuracy: 0.15833333333333333
# Accuracy: 0.18
# Precision: 0.08
# Recall: 0.18
# F1 Score: 0.07
# Confusion Matrix:
# [[ 7  3  0  0  0  0  0  0  0  0]
#  [ 0 10  0  0  0  0  0  0  0  0]
#  [ 3  7  0  0  0  0  0  0  0  0]
#  [ 5  4  0  0  0  0  1  0  0  0]
#  [ 3  7  0  0  0  0  0  0  0  0]
#  [ 6  4  0  0  0  0  0  0  0  0]
#  [ 1  8  0  0  0  0  1  0  0  0]
#  [ 6  4  0  0  0  0  0  0  0  0]
#  [ 7  3  0  0  0  0  0  0  0  0]
#  [ 2  8  0  0  0  0  0  0  0  0]]
# /Users/Razvan/Uni/dummy-snn/venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
visualize_neurons_weights(model2, 0, 24)
